# %% [markdown]
# Python is a high-level, interpreted, general-purpose programming language.
#
# It was created by Guido van Rossum and first released in 1991.
# Key Features of Python:
#
# Easy to Learn and Read
#
# Simple syntax similar to English
#
# Ideal for beginners
#
# Interpreted Language
#
# Python code runs line by line (no need to compile)
#
# High-Level Language
#
# Handles memory management automatically
#
# Abstracts low-level details
#
# Dynamic Typing
#
# Variables don’t need explicit data types
#
# Type is determined at runtime
#
# Object-Oriented
#
# Supports classes, objects, inheritance, etc.
#
# Extensive Libraries
#
# math, random, os, sys, numpy, pandas, tensorflow, etc.
#
# Cross-Platform
#
# Works on Windows, macOS, Linux
#
# Open Source
#
# Free to use and has a huge community

# %% [markdown]
# Variables in Python
#
# A variable is used to store data in memory.
#
# 🔹 Common Data Types in Python
#
# int → Integer numbers
#
# float → Decimal numbers
#
# str → Text
#
# bool → True / False

# %%
# Variables
x = 10          # Integer
y = 3.5         # Float
name = "Python" # String
is_active = True  # Boolean

# Print values
print(x)
print(y)
print(name)
print(is_active)

# Check data types
print(type(x))
print(type(y))
print(type(name))
print(type(is_active))
# Out:
# 10
# 3.5
# Python
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Output in Python
#
# We use the print() function to display output.

# %%
print("Hello World")
print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %% [markdown]
# Input in Python
#
# We use the input() function to take input from the user.
#
# input() always returns string data.

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: ss
# Hello ss

# %% [markdown]
# Operators in Python
#
# Arithmetic Operators are used to perform operations on variables and values.

# %%
a = 10
b = 3

print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
print(a % b)   # Modulus
print(a ** b)  # Power
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000

# %% [markdown]
# Comparison Operators
#
# Used to compare two values.

# %%
x = 5
y = 10

print(x == y)
print(x != y)
print(x > y)
print(x < y)
# Out:
# False
# True
# False
# True

# %% [markdown]
# Logical Operators
#
# Used to combine conditions.

# %%
a = True
b = False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# if Statement
#
# Executes code only if the condition is true.

# %%
num = 10

if num > 0:
    print("Positive number")
# Out:
# Positive number

# %% [markdown]
# if - else
#
# Used when there are two conditions.

# %%
num = -5

if num > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %% [markdown]
# if – elif – else
#
# Used when there are multiple conditions. elif means “else if”

# %%
num = 0

if num > 0:
    print("Positive")
elif num == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Zero

# %% [markdown]
# For Loop
#
# Used when the number of iterations is known

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# While Loop
#
# Runs as long as the condition is True.

# %%
count = 0

while count < 3:
    print("Count:", count)
    count += 1
# Out:
# Count: 0
# Count: 1
# Count: 2

# %% [markdown]
# Loop Control Statements
# break – exits the loop
# continue – skips current iteration

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %% [markdown]
# Lists in Python
#
# A list is a collection of items that is: Ordered, Mutable (can be changed), Allows duplicate values
# Key Points
#
# ✔ Lists are changeable
# ✔ Index starts from 0
# ✔ Useful for storing multiple values

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Modifying a list
numbers[1] = 20
print(numbers)
# Out:
# [1, 20, 3, 4, 5]

# %%
#add elements to a list
numbers.append(6)
#numbers.insert(1, 10)
print(numbers)
# Out:
# [1, 20, 3, 4, 5, 6]

# %%
numbers.insert(1, 10)
numbers
# Out:
# [1, 10, 20, 3, 4, 5, 6]

# %%
#remove elements in a list
numbers.remove(10)
#numbers.pop()
print(numbers)
# Out:
# [1, 20, 3, 4, 5, 6]

# %%
numbers.pop(1) #pop(index)
# Out:
# 20

# %%
#looping through list
for num in numbers:
    print(num)
# Out:
# 1
# 3
# 4
# 5
# 6

# %% [markdown]
# Tuples
#
# A tuple is:Ordered, Immutable (cannot be changed), Allows duplicates

# %%
my_tuple = (1, 2, 3, 3)
print(my_tuple)

print(my_tuple[0])   # Access element
# Out:
# (1, 2, 3, 3)
# 1

# %% [markdown]
# Sets
# A set is: Unordered, Mutable, and Does NOT allow duplicates

# %%
my_set = {1, 2, 3, 3, 4}
print(my_set)   # Duplicates removed
# Out:
# {1, 2, 3, 4}

# %%
#sets operations
a = {1, 2, 3}
b = {3, 4, 5}

print(a | b)   # Union
print(a & b)   # Intersection
print(a - b)   # Difference
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [markdown]
# Dictionaries in Python
#
# A dictionary stores data in key–value pairs.

# %%
#creating a dictionary
student = {
    "name": "John",
    "age": 21,
    "course": "Python"
}

print(student)
# Out:
# {'name': 'John', 'age': 21, 'course': 'Python'}

# %%
#accessing values
print(student["name"])
print(student.get("age"))
# Out:
# John
# 21

# %%
#Modifying dict.
student["age"] = 22
student["city"] = "Toronto"

print(student)
# Out:
# {'name': 'John', 'age': 22, 'course': 'Python', 'city': 'Toronto'}

# %%
#removing items
student.pop("city")
print(student)
# Out:
# {'name': 'John', 'age': 22, 'course': 'Python'}

# %%
#looping through dictionary
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : John
# age : 22
# course : Python

# %% [markdown]
# Functions: A function is a block of reusable code that performs a specific task.

# %%
def greet():
    print("Hello, Python!")

greet()  # Calling the function
# Out:
# Hello, Python!

# %%
# function with parameters
def add(a, b):
    return a + b

result = add(5, 3)
print("Sum:", result)
# Out:
# Sum: 8

# %%
#function with default parameter
def greet(name="Guest"):
    print("Hello,", name)

greet()           # Hello, Guest
greet("Alice")    # Hello, Alice
# Out:
# Hello, Guest
# Hello, Alice

# %%
#Lambda (Anonymous) Functions
square = lambda x: x * x
print(square(5))  # Output: 25
# Out:
# 25

# %% [markdown]
# Exception Handling in Python
#
# Exceptions are errors that occur during program execution.
# Python provides a way to handle exceptions gracefully using try, except, finally.

# %%
#basic try- except
try:
    num = int(input("Enter a number: "))
    print("You entered:", num)
except ValueError:
    print("Invalid input! Please enter a number.")
# Out:
# Enter a number: 6
# You entered: 6

# %%
#handeling multiple exceptions
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid value!")
# Out:
# Cannot divide by zero!

# %% [markdown]
# Key Points:
#
# ✔ try → code that might cause error,
# ✔ except → handles specific error,
# ✔ finally → runs always

# %%
try:
    f = open("sample.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found!")
finally:
    print("Execution completed.")
# Out:
# File not found!
# Execution completed.

# %% [markdown]
# Object-Oriented Programming (OOP) – Classes in Python.
# Classes and Objects in Python:
# A class is a blueprint for creating objects.
# An object is an instance of a class.

# %%
# Define a class
class Person:
    def __init__(self, name, age):
        self.name = name  # Instance variable
        self.age = age

    def display(self):
        print("Name:", self.name, "Age:", self.age)

# Create objects
person1 = Person("Alice", 25)
person2 = Person("Bob", 30)

# Access methods
person1.display()
person2.display()
# Out:
# Name: Alice Age: 25
# Name: Bob Age: 30

# %% [markdown]
# Key Concepts
#
# __init__ → Constructor, automatically runs when object is created
#
# Instance variables → Belong to the object (self.name)
#
# Methods → Functions inside a class (display())
#
# Objects → Instances of a class
